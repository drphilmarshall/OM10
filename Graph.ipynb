# %%
import color
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches
# %matplotlib inline

# %%
r, g, i, z = color.CalculateMagnitude('/Users/Jenny/Desktop/slq/om10/data/qso_mock.fits', 'lens')

# %%
# work more on design

x = np.array([1,2,3,4])
y = np.array([r,g,i,z])
my_xticks = ['R','G','I','Z']
plt.xticks(x, my_xticks)
quasar = plt.plot(x, y, 'bo-')
plt.ylabel('Apparent Magnitude')
plt.gca().invert_yaxis()
plt.xlabel('Bands')
lens_patch = mpatches.Patch(color='blue', label='Lens')
quasar_patch = mpatches.Patch(color='red', label='Quasar')
plt.legend(handles=[lens_patch, quasar_patch])
