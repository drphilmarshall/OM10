# %%
import color
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches
# %matplotlib inline
# Out:
# /Users/Jenny/anaconda/envs/python2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
r_l, g_l, i_l, z_l = color.CalculateMagnitude('datapath', 'lens')
r_s, g_s, i_s, z_s = color.CalculateMagnitude('datapath', 'source')

# %%
x = np.array([1,2,3,4])
y_1 = np.array([r_l,g_l,i_l,z_l])
y_s = np.array([r_s,g_s,i_s,z_s])
#BUG!!!! MAGNITUDE NOT DEPENDENT ON SED VELDISP AND REDSHIFT T_T
print y_1-y_s
xticks = ['R','G','I','Z']
plt.xticks(x, xticks)
quasar = plt.plot(x, y_s, 'ro-', label = 'quasar')
lens = plt.plot(x, y_s, 'bo-', label = 'lens')
plt.ylabel('Apparent Magnitude')
plt.gca().invert_yaxis()
plt.xlabel('Bands')
#lens_patch = mpatches.Patch(color='blue', label='Lens')
#quasar_patch = mpatches.Patch(color='red', label='Quasar')
#plt.legend(lens)
#plt.legend(quasar)
plt.legend()
# Out:
# [ 0.  0.  0.  0.]
