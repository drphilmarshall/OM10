# %%
# %run 'paint_lens_qso.py'
# Out:
# out of the region!
# Lens Properties
# redshift  sigma  g Reff  r   i    z   g mag   r mag   i mag   z   w1    w2    w3   w4
# [  0.35691865  96.44085461   7.26955753   2.85934251   1.93660696
#    0.43752283  15.7764489   14.34586288  13.66926317  13.26571247
#   10.65585152  10.66470226   8.8052511    6.48342141]
# out of the region!
# QSO Properties
# redshift   g     r     i     z     w1      w2       w3     w4
# [ 0.91923884  5.02670954  4.85212112  4.73490448  4.65070856  3.68078726
#   3.51090638  2.70748322  1.9754314 ]

# %%
print '$OM10_DIR'
# Out:
# $OM10_DIR

# %%
open('$OM10_DIR/LICENSE')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-4-b5c2d10018f8> in <module>()
# ----> 1 open('$OM10_DIR/LICENSE')
#
# IOError: [Errno 2] No such file or directory: '$OM10_DIR/LICENSE'

# %%
import os
os.path.expandvars("$OM10_DIR/data/qso_mock.fits")
# Out:
# '/Users/mbaumer/pybin/OM10/data/qso_mock.fits'

# %%
# %run 'db.py'
# Out:
# om10.DB: read in LRG data from  /Users/mbaumer/pybin/OM10/data/CFHTLS_LRGs.txt
# om10.DB: number of LRGs stored =  10000
# WARNING: Lens  0  has no matching LRGs, skipping...
# WARNING: Lens  1  has no matching LRGs, skipping...
# WARNING: Lens  2  has no matching LRGs, skipping...
# WARNING: Lens  3  has no matching LRGs, skipping...
# WARNING: Lens  4  has no matching LRGs, skipping...
# WARNING: Lens  5  has no matching LRGs, skipping...
# WARNING: Lens  6  has no matching LRGs, skipping...
# WARNING: Lens  7  has no matching LRGs, skipping...
# WARNING: Lens  8  has no matching LRGs, skipping...
# WARNING: Lens  9  has no matching LRGs, skipping...
# WARNING: Lens  10  has no matching LRGs, skipping...
# WARNING: Lens  11  has no matching LRGs, skipping...
# WARNING: Lens  12  has no matching LRGs, skipping...
# WARNING: Lens  13  has no matching LRGs, skipping...
# WARNING: Lens  14  has no matching LRGs, skipping...
# WARNING: Lens  15  has no matching LRGs, skipping...
# ...

# %%
db.sample.names
# Out:
# ['LENSID',
#  'FLAGTYPE',
#  'NIMG',
#  'ZLENS',
#  'VELDISP',
#  'ELLIP',
#  'PHIE',
#  'GAMMA',
#  'PHIG',
#  'ZSRC',
#  'XSRC',
#  'YSRC',
#  'MAGI_IN',
#  'MAGI',
#  'IMSEP',
#  'XIMG',
#  'YIMG',
#  'MAG',
#  'DELAY',
#  'KAPPA',
#  'FSTAR',
#  'DD',
#  'DDLUM',
#  'ABMAG_I',
#  'APMAG_I',
#  'KCORR',
#  'DS',
#  'DDS',
#  'SIGCRIT',
#  'DSLUM',
#  'L_I',
#  'REFF',
#  'REFF_T']
