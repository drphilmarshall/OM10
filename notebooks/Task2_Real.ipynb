# %%
#%matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline 
from __future__ import division
import os, numpy as np
import matplotlib
matplotlib.use('TkAgg')
matplotlib.rc('text', usetex=False)
import corner
# I changed plotting.py - change to numpy
# om10 changed
import om10
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ndim, nsamples = 5, 10000
samples = np.random.randn(ndim * nsamples).reshape([nsamples, ndim])
figure = corner.corner(samples)
figure.savefig("corner.png")

# %%
db = om10.DB()

# Pull out a specific lens and plot it:
id = 7176527
lens = db.get_lens(id)
print lens
om10.plot_lens(lens)
# Out:
# Looking for catalog  qso_mock.fits
# LENSID FLAGTYPE NIMG ZLENS VELDISP ELLIP ... DDS SIGCRIT DSLUM L_I REFF REFF_T
# ------ -------- ---- ----- ------- ----- ... --- ------- ----- --- ---- ------
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-60408c9504f7> in <module>()
#       5 lens = db.get_lens(id)
#       6 print lens
# ----> 7 om10.plot_lens(lens)
#
# /Users/Jenny/anaconda/envs/python2/lib/python2.7/site-packages/om10/plotting.pyc in plot_lens(lens, saveImg, IQ)
#     251
#     252     # Pull out data for ease of use:
# --> 253     id = lens['LENSID'][0]
#     254     xi = lens['XIMG'][0]
#     255     yi = lens['YIMG'][0]
#
# astropy/table/_column_mixins.pyx in astropy.table._column_mixins._ColumnGetitemShim.__getitem__ (astropy/table/_column_mixins.c:942)()
#
# ...

# %%
db = om10.DB(catalog='/Users/Jenny/Desktop/om10fork/om10/data/qso_mock.fits')
print db.lenses

# %%
# Pull out a specific lens and plot it:
id = 14428
lens = db.get_lens(id)
om10.plot_sample(lens, saveImg=True)

# %%
matplotlib.rc('text', usetex=False)
ndim, nsamples = 5, 10000
samples = np.random.randn(ndim * nsamples).reshape([nsamples, ndim])
figure = corner.corner(samples)
figure.savefig("corner.png")

# %%
quads, doubles = {}, {}

LSST = om10.DB()
LSST.select_random(maglim=23.3, area=18000.0, IQ=0.7)

quads['LSST'] = LSST.sample[LSST.sample['NIMG'] == 4]
doubles['LSST'] = LSST.sample[LSST.sample['NIMG'] == 2]
print 'q'
print quads['LSST']
print 'd'
print doubles['LSST']

# %%
fig = om10.plot_sample(doubles['LSST'], color='blue')
# fig = om10.plot_sample(quads['LSST'], color='red', fig=fig) This line doesn't work

# %%
db.paint(synthetic=True, target='lens')
print db.lenses

# %%
# HOW TO OVERLAP THE CORNERPLOTS
fig = corner.corner(samples1)
corner.corner(samples2, fig=fig)
